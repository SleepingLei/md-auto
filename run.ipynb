# %%
# 用rosetta对初始结构建模
import os
import subprocess

def pdb_modify_name(pdb_pwd, out_pdb_pwd):
    with open(pdb_pwd, "r") as ifile:
        lines = ifile.readlines()
        out_lines = []
        for line in lines:
            if not line.startswith("ATOM"):
                continue
            resid = line[22:26]
            res_atom = line[12:16].strip()
            atom_type = line[77]
            if int(resid) == 1 and res_atom in ["P", "OP1", "OP2"]:
                continue
            elif atom_type == "H":
                continue
            out_lines.append(line)
    with open(out_pdb_pwd, "w") as ifile:
        for line in out_lines:
            ifile.write(line)

def sbatch_farfar2(work_dir, seq, rna_ss, out_pdb):
    start_pwd = os.getcwd()
    os.makedirs(work_dir, exist_ok=True)
    os.chdir(work_dir)
    with open(f"farfar2.slurm", "w") as ifile:
        ifile.write(f"""#!/bin/bash
#SBATCH --job-name=farfar2
#SBATCH --output=farfar2.out
#SBATCH --error=farfar2.err
#SBATCH --nodes=1
#SBATCH --cpus-per-task=8
#SBATCH --gres=gpu:1
#SBATCH --time=240:00:00
#SBATCH --partition=4090

source /mnt/beegfs/opt/module/tools/modules/init/bash
module load rosetta/3.14-mpi

rna_denovo.cxx11threadmpiserialization.linuxgccrelease -sequence "{seq.lower()}" -secstruct "{rna_ss}" -nstruct 1 -out:file:silent test.out -minimize_rna true -overwrite true
rna_minimize.cxx11threadmpiserialization.linuxgccrelease -in:file:silent test.out -out:pdb true
cp S_000001_minimize.pdb {out_pdb}
"""
)
    subprocess.run(f"sbatch farfar2.slurm", shell=True)
    os.chdir(start_pwd)


input_txt = "/gene/home/ldw/Desktop/RNA_ensemble/input/dna_repair.txt"
save_dir = "/gene/home/ldw/Desktop/RNA_ensemble/input/dna_repair"
rna_infos = {}
with open(input_txt, "r") as ifile:
    for line in ifile.readlines():
        words = line.split()
        rna_infos[words[0]] = {"seq": words[1], "rna_ss": words[2]}

for name in rna_infos:
    seq = rna_infos[name]['seq']
    rna_ss = rna_infos[name]['rna_ss']
    if len(seq) != len(rna_ss):
        print(name, len(seq), len(rna_ss), seq, rna_ss)
    work_dir = os.path.join(save_dir, name)
    out_pdb = os.path.join(save_dir, f"{name}.pdb")
    sbatch_farfar2(work_dir, seq, rna_ss, out_pdb)
# Out:
# Submitted batch job 210847

# %%
# 对rosetta输出的结构进行清洗
for name in rna_infos:
    out_pdb = os.path.join(save_dir, f"{name}.pdb")
    pdb_modify_name(out_pdb, out_pdb)

# %%
# 基于rosetta产生的初始结构进行模拟
from md import construct_top, run_md
import os


traj_ns = 500  # 500 ns
num_of_replica = 3  # 平行轨迹数
box_d = 12  # 水盒子大小
k_m = 0.12  # 0.12 M K+
mg_m = 0.02  # 0.02 M Mg2+
temp = 400  # 400 K
ff = "ljbb"  # RNA force field
wat_ff = "opc3"  # water force field
input_txt = "/gene/home/ldw/Desktop/RNA_ensemble/input/input-primirna.fasta"
save_dir = "/gene/home/ldw/Desktop/RNA_ensemble/input"  # 初始pdb结构路径
md_pwd = "/gene/home/ldw/Desktop/RNA_ensemble/md"  # md路径
os.makedirs(md_pwd, exist_ok=True)

rna_infos = {}
with open(input_txt, "r") as ifile:
    for line in ifile.readlines():
        words = line.split()
        rna_infos[words[0]] = {"seq": words[1], "rna_ss": words[2]}

for rna_name in list(rna_infos.keys())[:]:
    pdb_pwd = os.path.join(save_dir, f"{rna_name}.pdb")
    rna_ss = rna_infos[rna_name]["rna_ss"]
    seq = rna_infos[rna_name]["seq"]
    work_pwd = os.path.join(md_pwd, f"{rna_name}_{ff}_{wat_ff}_{temp}K_{traj_ns}ns_{k_m}k_{mg_m}mg")
    top = construct_top(pdb_pwd, seq, rna_ss, work_pwd, mg_m, k_m, box_d, ff, wat_ff)
    top = "system.hmr.top"
    for replica in range(num_of_replica):
        run_md(work_pwd, top, replica, temp=temp, ns=traj_ns)
# Out:
# /gene/home/ldw/Desktop/RNA_ensemble/md/pri-miR159a_ljbb_opc3_400K_500ns_0.12k_0.02mg
# Water molecules: 9840
# -I: Adding /gene/home/ldw/miniconda3/envs/amber_test/dat/leap/prep to search path.
# -I: Adding /gene/home/ldw/miniconda3/envs/amber_test/dat/leap/lib to search path.
# -I: Adding /gene/home/ldw/miniconda3/envs/amber_test/dat/leap/parm to search path.
# -I: Adding /gene/home/ldw/miniconda3/envs/amber_test/dat/leap/cmd to search path.
# -f: Source system.tleap.
#
# Welcome to LEaP!
# (no leaprc in search path)
# Sourcing: ./system.tleap
# ----- Source: /gene/home/ldw/miniconda3/envs/amber_test/dat/leap/cmd/leaprc.RNA.LJbb
# ----- Source of /gene/home/ldw/miniconda3/envs/amber_test/dat/leap/cmd/leaprc.RNA.LJbb done
# Log file: ./leap.log
# Loading parameters: /gene/home/ldw/miniconda3/envs/amber_test/dat/leap/parm/parm10.dat
# Reading title:
# PARM99 + frcmod.ff99SB + frcmod.parmbsc0 + OL3 for RNA
# Loading library: /gene/home/ldw/miniconda3/envs/amber_test/dat/leap/lib/nucleic12.LJbb-RNA.lib
# Loading library: /gene/home/ldw/miniconda3/envs/amber_test/dat/leap/lib/terminalphos.LJbb-RNA.lib
# Loading parameters: /gene/home/ldw/miniconda3/envs/amber_test/dat/leap/parm/frcmod.RNA.LJbb
# Reading force field modification type file (frcmod)
# Reading title:
# Steinbrecher-Latzer-Case Phosphate Oxygen parameters (JCTC, 8, 4405-12, 2012)
# ----- Source: /gene/home/ldw/miniconda3/envs/amber_test/dat/leap/cmd/leaprc.water.opc3
# ----- Source of /gene/home/ldw/miniconda3/envs/amber_test/dat/leap/cmd/leaprc.water.opc3 done
# Loading library: /gene/home/ldw/miniconda3/envs/amber_test/dat/leap/lib/atomic_ions.lib
# Loading library: /gene/home/ldw/miniconda3/envs/amber_test/dat/leap/lib/solvents.lib
# Loading parameters: /gene/home/ldw/miniconda3/envs/amber_test/dat/leap/parm/frcmod.opc3
# Reading force field modification type file (frcmod)
# Reading title:
# OPC3 Water Model (Izadi and Onufriev,  145, 074501, 2016)
# Loading parameters: /gene/home/ldw/miniconda3/envs/amber_test/dat/leap/parm/frcmod.ionslm_126_opc3
# Reading force field modification type file (frcmod)
# Reading title:
# Li/Merz ion parameters of atomic ions for the OPC3 water model (12-6 set)
# Loading PDB file: ./system.pdb
#   Added missing heavy atom: .R<A5 1>.A<O5' 2>
#   total atoms in file: 1146
#   Leap added 5 missing atoms according to residue templates:
#        1 Heavy
#        4 H / lone pairs
# Checking Unit.
#
# /gene/home/ldw/miniconda3/envs/amber_test/bin/teLeap: Warning!
# The unperturbed charge of the unit (-35.000000) is not zero.
#
# /gene/home/ldw/miniconda3/envs/amber_test/bin/teLeap: Note.
# Ignoring the warning from Unit Checking.
#
# Building topology.
# Building atom parameters.
# Building bond parameters.
# Building angle parameters.
# Building proper torsion parameters.
# Building improper torsion parameters.
#  total 243 improper torsions applied
# Building H-Bond parameters.
# Incorporating Non-Bonded adjustments.
# Not Marking per-residue atom chain types.
# Marking per-residue atom chain types.
#  (no restraints)
# Writing pdb file: system.check.nosol.pdb
# Scaling up box by a factor of 1.478420 to meet diagonal cut criterion
#   Solute vdw bounding box:              37.397 32.290 51.745
#   Total bounding box for atom centers:  87.227 87.227 87.227
#       (box expansion for 'iso' is  54.0%)
#   Solvent unit box:                     18.682 18.750 18.542
#   Volume: 343384.179 A^3 (oct)
#   Total mass 189112.600 amu,  Density 0.915 g/cc
#   Added 9859 residues.
# Adding 3 counter ions to "complex". 9856 solvent molecules will remain.
# 0: Placed MG in complex at (8.69, 21.21, 12.98).
# 0: Placed MG in complex at (-8.87, -16.09, 11.89).
# 0: Placed MG in complex at (-7.77, 23.46, -22.26).
# Adding 21 counter ions to "complex". 9835 solvent molecules will remain.
# 0: Placed K+ in complex at (18.60, 6.86, -24.07).
# 0: Placed K+ in complex at (11.93, -22.15, -26.75).
# 0: Placed K+ in complex at (13.37, 16.49, 13.32).
# 0: Placed K+ in complex at (-28.40, 22.48, 18.39).
# 0: Placed K+ in complex at (20.61, -13.49, 25.37).
# 0: Placed K+ in complex at (35.95, 2.91, -11.18).
# 0: Placed K+ in complex at (9.45, 12.37, 23.14).
# 0: Placed K+ in complex at (26.66, 23.93, -20.40).
# 0: Placed K+ in complex at (25.74, 22.27, 1.76).
# 0: Placed K+ in complex at (-1.98, -20.26, 15.94).
# 0: Placed K+ in complex at (-35.09, 1.01, 23.28).
# 0: Placed K+ in complex at (-0.82, -1.35, 25.92).
# 0: Placed K+ in complex at (-14.98, 11.78, -3.19).
# 0: Placed K+ in complex at (7.67, -2.57, -39.30).
# 0: Placed K+ in complex at (-7.67, -20.90, -31.01).
# 0: Placed K+ in complex at (-10.99, 15.82, -0.36).
# 0: Placed K+ in complex at (37.09, 10.96, 22.07).
# 0: Placed K+ in complex at (15.57, 8.17, -17.72).
# 0: Placed K+ in complex at (15.39, -22.04, -4.57).
# 0: Placed K+ in complex at (-23.53, -14.63, -16.02).
# 0: Placed K+ in complex at (-28.49, -3.61, -7.22).
# 8 K+ ions required to neutralize.
# Adding 8 counter ions to "complex". 9827 solvent molecules will remain.
# 0: Placed K+ in complex at (10.91, -5.46, -26.57).
# 0: Placed K+ in complex at (36.34, 18.66, -15.13).
# 0: Placed K+ in complex at (12.87, 34.33, -0.29).
# 0: Placed K+ in complex at (6.00, 29.35, 9.70).
# 0: Placed K+ in complex at (-16.31, -28.45, -9.19).
# 0: Placed K+ in complex at (-36.86, 11.70, 23.11).
# 0: Placed K+ in complex at (29.17, -9.33, -11.52).
# 0: Placed K+ in complex at (13.14, -31.93, -4.39).
#
# /gene/home/ldw/miniconda3/envs/amber_test/bin/teLeap: Warning!
# addIonsRand: 1st Ion & target unit have charges of the same sign:
#      unit charge = -6.96829e-11; ion1 charge = -1;
#      can't neutralize.
# Total unperturbed charge:  -0.000000
# Total perturbed charge:    -0.000000
# Checking Unit.
# Building topology.
# Building atom parameters.
# Building bond parameters.
# Building angle parameters.
# Building proper torsion parameters.
# Building improper torsion parameters.
#  total 243 improper torsions applied
# Building H-Bond parameters.
# Incorporating Non-Bonded adjustments.
# Not Marking per-residue atom chain types.
# Marking per-residue atom chain types.
#   (Residues lacking connect0/connect1 -
#    these don't have chain types marked:
#
# 	res	total affected
#
# 	WAT	9827
#   )
#  (no restraints)
# Writing pdb file: system.check.pdb
#    printing CRYST1 record to PDB file with box info
# 	Quit
#
# Exiting LEaP: Errors = 0; Warnings = 2; Notes = 1.
#
#  _~__________________
#  |_|_______________|_|
#  |  ,-------------.  |
#  | |  .---------.  | |
#  | |  |P        |  | |
#  | |  | a       |  | |
#  | |  |  r      |  | |
#  | |  |   m  ED |  | |
#  | |  `---------'  | |
#  | `---------------' |
#  |   _ ParmedBoy     |
#  | _| |_         ,-. |
#  ||_ O _|   ,-. "._,"|
#  |  |_|    "._,"   A |
#  |    _  _    B      |
#  |   // //           |
#  |  // //    \\\\\\  |
#  |  `  `      \\\\\\ ,
#  |________...______,"
#
# ParmEd: a Parameter file Editor
#
#
# Loaded Amber topology file system.top
# ['system.parmed']
# Reading actions from system.parmed
#
# Repartitioning hydrogen masses to 3.024 daltons. Not changing water hydrogen masses.
# Outputting Amber topology file system.hmr.top
# Done!
#
# CPPTRAJ: Trajectory Analysis. V6.18.1 (AmberTools)
#     ___  ___  ___  ___
#      | \/ | \/ | \/ |
#     _|_/\_|_/\_|_/\_|_
#
# | Date/time: 08/10/25 18:58:10
# | Available memory: 20.708 GB
#
# INPUT: Reading input from 'rst.cpptraj'
#   [parm system.check.nosol.pdb]
# 	Reading 'system.check.nosol.pdb' as PDB File
# 	Reading bond info from CONECT records.
# 	Not reading bond info from LINK records.
# Warning: PDB line length is short (67 chars, expected 80).
# 	Determining bond info from distances.
# Warning: Determining bond length parameters from element types for 'system.check.nosol.pdb'.
#   [rst :13@N3 :25@N1 r1 2 r2 2.5 r3 3.1 r4 5 rk2 10.0 rk3 10.0 out distance.rst]
# 	Mask [:13@N3] corresponds to 1 atoms.
# 	Mask [:25@N1] corresponds to 1 atoms.
#   [rst :12@N3 :26@N1 r1 2 r2 2.5 r3 3.1 r4 5 rk2 10.0 rk3 10.0 out distance.rst]
# 	Mask [:12@N3] corresponds to 1 atoms.
# 	Mask [:26@N1] corresponds to 1 atoms.
#   [rst :11@N3 :27@N1 r1 2 r2 2.5 r3 3.1 r4 5 rk2 10.0 rk3 10.0 out distance.rst]
# 	Mask [:11@N3] corresponds to 1 atoms.
# 	Mask [:27@N1] corresponds to 1 atoms.
#   [rst :10@N3 :28@N1 r1 2 r2 2.5 r3 3.1 r4 5 rk2 10.0 rk3 10.0 out distance.rst]
# 	Mask [:10@N3] corresponds to 1 atoms.
# 	Mask [:28@N1] corresponds to 1 atoms.
#   [rst :9@N3 :29@N1 r1 2 r2 2.5 r3 3.1 r4 5 rk2 10.0 rk3 10.0 out distance.rst]
# 	Mask [:9@N3] corresponds to 1 atoms.
# 	Mask [:29@N1] corresponds to 1 atoms.
#   [rst :8@N1 :30@N3 r1 2 r2 2.5 r3 3.1 r4 5 rk2 10.0 rk3 10.0 out distance.rst]
# 	Mask [:8@N1] corresponds to 1 atoms.
# 	Mask [:30@N3] corresponds to 1 atoms.
#   [rst :7@N1 :31@N3 r1 2 r2 2.5 r3 3.1 r4 5 rk2 10.0 rk3 10.0 out distance.rst]
# 	Mask [:7@N1] corresponds to 1 atoms.
# 	Mask [:31@N3] corresponds to 1 atoms.
#   [rst :4@N3 :33@N1 r1 2 r2 2.5 r3 3.1 r4 5 rk2 10.0 rk3 10.0 out distance.rst]
# 	Mask [:4@N3] corresponds to 1 atoms.
# 	Mask [:33@N1] corresponds to 1 atoms.
#   [rst :3@N3 :34@N1 r1 2 r2 2.5 r3 3.1 r4 5 rk2 10.0 rk3 10.0 out distance.rst]
# 	Mask [:3@N3] corresponds to 1 atoms.
# 	Mask [:34@N1] corresponds to 1 atoms.
#   [rst :2@N1 :35@N3 r1 2 r2 2.9 r3 4.1 r4 6 rk2 10.0 rk3 10.0 out distance.rst]
# 	Mask [:2@N1] corresponds to 1 atoms.
# 	Mask [:35@N3] corresponds to 1 atoms.
# TIME: Total execution time: 0.0063 seconds.
# --------------------------------------------------------------------------------
# To cite CPPTRAJ use:
# Daniel R. Roe and Thomas E. Cheatham, III, "PTRAJ and CPPTRAJ: Software for
#   Processing and Analysis of Molecular Dynamics Trajectory Data". J. Chem.
#   Theory Comput., 2013, 9 (7), pp 3084-3095.
#
# Submitted batch job 214187
# Submitted batch job 214188
# Submitted batch job 214189
# /gene/home/ldw/Desktop/RNA_ensemble/md/pri-miR159b_ljbb_opc3_400K_500ns_0.12k_0.02mg
# Water molecules: 11455
# -I: Adding /gene/home/ldw/miniconda3/envs/amber_test/dat/leap/prep to search path.
# -I: Adding /gene/home/ldw/miniconda3/envs/amber_test/dat/leap/lib to search path.
# -I: Adding /gene/home/ldw/miniconda3/envs/amber_test/dat/leap/parm to search path.
# -I: Adding /gene/home/ldw/miniconda3/envs/amber_test/dat/leap/cmd to search path.
# -f: Source system.tleap.
#
# Welcome to LEaP!
# (no leaprc in search path)
# Sourcing: ./system.tleap
# ----- Source: /gene/home/ldw/miniconda3/envs/amber_test/dat/leap/cmd/leaprc.RNA.LJbb
# ----- Source of /gene/home/ldw/miniconda3/envs/amber_test/dat/leap/cmd/leaprc.RNA.LJbb done
# Log file: ./leap.log
# Loading parameters: /gene/home/ldw/miniconda3/envs/amber_test/dat/leap/parm/parm10.dat
# Reading title:
# PARM99 + frcmod.ff99SB + frcmod.parmbsc0 + OL3 for RNA
# Loading library: /gene/home/ldw/miniconda3/envs/amber_test/dat/leap/lib/nucleic12.LJbb-RNA.lib
# Loading library: /gene/home/ldw/miniconda3/envs/amber_test/dat/leap/lib/terminalphos.LJbb-RNA.lib
# Loading parameters: /gene/home/ldw/miniconda3/envs/amber_test/dat/leap/parm/frcmod.RNA.LJbb
# Reading force field modification type file (frcmod)
# Reading title:
# Steinbrecher-Latzer-Case Phosphate Oxygen parameters (JCTC, 8, 4405-12, 2012)
# ----- Source: /gene/home/ldw/miniconda3/envs/amber_test/dat/leap/cmd/leaprc.water.opc3
# ----- Source of /gene/home/ldw/miniconda3/envs/amber_test/dat/leap/cmd/leaprc.water.opc3 done
# Loading library: /gene/home/ldw/miniconda3/envs/amber_test/dat/leap/lib/atomic_ions.lib
# Loading library: /gene/home/ldw/miniconda3/envs/amber_test/dat/leap/lib/solvents.lib
# Loading parameters: /gene/home/ldw/miniconda3/envs/amber_test/dat/leap/parm/frcmod.opc3
# Reading force field modification type file (frcmod)
# Reading title:
# OPC3 Water Model (Izadi and Onufriev,  145, 074501, 2016)
# Loading parameters: /gene/home/ldw/miniconda3/envs/amber_test/dat/leap/parm/frcmod.ionslm_126_opc3
# Reading force field modification type file (frcmod)
# Reading title:
# Li/Merz ion parameters of atomic ions for the OPC3 water model (12-6 set)
# Loading PDB file: ./system.pdb
#   Added missing heavy atom: .R<A5 1>.A<O5' 2>
#   total atoms in file: 1353
#   Leap added 5 missing atoms according to residue templates:
#        1 Heavy
#        4 H / lone pairs
# Checking Unit.
#
# /gene/home/ldw/miniconda3/envs/amber_test/bin/teLeap: Warning!
# The unperturbed charge of the unit (-42.000000) is not zero.
#
# /gene/home/ldw/miniconda3/envs/amber_test/bin/teLeap: Note.
# Ignoring the warning from Unit Checking.
#
# Building topology.
# Building atom parameters.
# Building bond parameters.
# Building angle parameters.
# Building proper torsion parameters.
# Building improper torsion parameters.
#  total 283 improper torsions applied
# Building H-Bond parameters.
# Incorporating Non-Bonded adjustments.
# Not Marking per-residue atom chain types.
# Marking per-residue atom chain types.
#  (no restraints)
# Writing pdb file: system.check.nosol.pdb
# Scaling up box by a factor of 1.144422 to meet diagonal cut criterion
#   Solute vdw bounding box:              29.526 28.807 64.111
#   Total bounding box for atom centers:  91.577 91.577 91.577
#       (box expansion for 'iso' is 161.5%)
#   Solvent unit box:                     18.682 18.750 18.542
#   Volume: 396721.264 A^3 (oct)
#   Total mass 220349.574 amu,  Density 0.922 g/cc
#   Added 11476 residues.
# Adding 4 counter ions to "complex". 11472 solvent molecules will remain.
# 0: Placed MG in complex at (-5.76, 0.49, 36.13).
# 0: Placed MG in complex at (-26.71, 8.44, 11.00).
# 0: Placed MG in complex at (-27.07, 20.17, 22.07).
# 0: Placed MG in complex at (4.03, -20.21, -7.02).
# Adding 24 counter ions to "complex". 11448 solvent molecules will remain.
# 0: Placed K+ in complex at (-37.49, -4.24, 12.47).
# 0: Placed K+ in complex at (10.48, -28.51, 18.63).
# 0: Placed K+ in complex at (-19.27, 11.84, -39.69).
# 0: Placed K+ in complex at (-15.91, 22.06, 6.98).
# 0: Placed K+ in complex at (19.93, -9.29, -16.79).
# 0: Placed K+ in complex at (-34.39, 29.17, 0.09).
# 0: Placed K+ in complex at (16.99, -11.02, 33.74).
# 0: Placed K+ in complex at (6.38, 4.05, -42.86).
# 0: Placed K+ in complex at (1.80, -22.38, 16.99).
# 0: Placed K+ in complex at (8.63, 44.17, 0.05).
# 0: Placed K+ in complex at (-19.72, 30.13, -12.47).
# 0: Placed K+ in complex at (2.03, -16.35, -24.21).
# 0: Placed K+ in complex at (-30.03, 10.66, -18.97).
# 0: Placed K+ in complex at (-22.63, 7.33, 1.55).
# 0: Placed K+ in complex at (-11.64, -1.91, 30.63).
# 0: Placed K+ in complex at (15.93, -34.23, -13.93).
# 0: Placed K+ in complex at (-4.94, -29.66, -28.77).
# 0: Placed K+ in complex at (-10.60, 19.45, -12.96).
# 0: Placed K+ in complex at (15.59, 8.36, -17.44).
# 0: Placed K+ in complex at (10.05, -20.85, -1.90).
# 0: Placed K+ in complex at (-5.72, 0.47, 9.66).
# 0: Placed K+ in complex at (26.50, -22.06, -17.49).
# 0: Placed K+ in complex at (10.45, 19.84, -11.42).
# 0: Placed K+ in complex at (-25.64, -14.85, -22.65).
# 10 K+ ions required to neutralize.
# Adding 10 counter ions to "complex". 11438 solvent molecules will remain.
# 0: Placed K+ in complex at (-26.31, -11.42, -3.72).
# 0: Placed K+ in complex at (-4.90, 18.86, -3.72).
# 0: Placed K+ in complex at (33.13, -19.21, -19.52).
# 0: Placed K+ in complex at (-9.99, 3.42, -11.74).
# 0: Placed K+ in complex at (-37.42, 25.05, 3.33).
# 0: Placed K+ in complex at (-14.12, 35.75, 27.21).
# 0: Placed K+ in complex at (-26.35, -11.39, 22.75).
# 0: Placed K+ in complex at (34.21, -26.17, -7.85).
# 0: Placed K+ in complex at (33.74, -9.94, 23.19).
# 0: Placed K+ in complex at (29.35, -9.66, 2.83).
#
# /gene/home/ldw/miniconda3/envs/amber_test/bin/teLeap: Warning!
# addIonsRand: 1st Ion & target unit have charges of the same sign:
#      unit charge = -8.11298e-11; ion1 charge = -1;
#      can't neutralize.
# Total unperturbed charge:  -0.000000
# Total perturbed charge:    -0.000000
# Checking Unit.
# Building topology.
# Building atom parameters.
# Building bond parameters.
# Building angle parameters.
# Building proper torsion parameters.
# Building improper torsion parameters.
#  total 283 improper torsions applied
# Building H-Bond parameters.
# Incorporating Non-Bonded adjustments.
# Not Marking per-residue atom chain types.
# Marking per-residue atom chain types.
#   (Residues lacking connect0/connect1 -
#    these don't have chain types marked:
#
# 	res	total affected
#
# 	WAT	11438
#   )
#  (no restraints)
# Writing pdb file: system.check.pdb
#    printing CRYST1 record to PDB file with box info
# 	Quit
#
# Exiting LEaP: Errors = 0; Warnings = 2; Notes = 1.
#
#                  ./       |      |        \.
#                .:(        |i __ j|        ):`.
#              .'   `._     |`::::'|     _.'    `.
#            .'        "---.j `::' f.---"         `.
#      _____/     ___    ____      __    __  ____   ___
#     |      \   |   |  |     `__'|  \  /  ||    | |   \
#     |  .-.  | .'   `| | .-.  |-/|   \/   || ___| |  . \
#     |  |_|  | |  i  | | |_| /"":|        || |    | | \ \
#     |       / | .^. | |    /::::|        || |__. | |  \ \
#     |  ----'  | | | | |    \ :: |        ||  __| | |  |  )
#     |  |     .' ''' `.|  |\ \   |  i  i  j| |    . | /  /
#     |  |     |   _   ||  | \ \  |  |\/|  || |__. | |.  / .
#    [|  |     |  | |  ||  |  \ \ |  |  |  ||    | |    /   ].
#   ] `--'     :--' `--::--'   \_|`--' ::--"|____|-"-- /    :[
#   |      __  ::-'''`.:' "--.    .----::.----:: ,.---._    :|
#   [  .-""  "`'              \  /      "      `'       `-. :].
#  ]:.'                        \/                          `.:[
#  |/                                                        \|
#
# ParmEd: a Parameter file Editor
#
#
# Loaded Amber topology file system.top
# ['system.parmed']
# Reading actions from system.parmed
#
# Repartitioning hydrogen masses to 3.024 daltons. Not changing water hydrogen masses.
# Outputting Amber topology file system.hmr.top
# Done!
#
# CPPTRAJ: Trajectory Analysis. V6.18.1 (AmberTools)
#     ___  ___  ___  ___
#      | \/ | \/ | \/ |
#     _|_/\_|_/\_|_/\_|_
#
# | Date/time: 08/10/25 18:58:15
# | Available memory: 20.669 GB
#
# INPUT: Reading input from 'rst.cpptraj'
#   [parm system.check.nosol.pdb]
# 	Reading 'system.check.nosol.pdb' as PDB File
# 	Reading bond info from CONECT records.
# 	Not reading bond info from LINK records.
# Warning: PDB line length is short (67 chars, expected 80).
# 	Determining bond info from distances.
# Warning: Determining bond length parameters from element types for 'system.check.nosol.pdb'.
#   [rst :19@N3 :23@N1 r1 2 r2 2.5 r3 3.1 r4 5 rk2 10.0 rk3 10.0 out distance.rst]
# 	Mask [:19@N3] corresponds to 1 atoms.
# 	Mask [:23@N1] corresponds to 1 atoms.
#   [rst :18@N1 :24@N3 r1 2 r2 2.5 r3 3.1 r4 5 rk2 10.0 rk3 10.0 out distance.rst]
# 	Mask [:18@N1] corresponds to 1 atoms.
# 	Mask [:24@N3] corresponds to 1 atoms.
#   [rst :17@N1 :25@N3 r1 2 r2 2.5 r3 3.1 r4 5 rk2 10.0 rk3 10.0 out distance.rst]
# 	Mask [:17@N1] corresponds to 1 atoms.
# 	Mask [:25@N3] corresponds to 1 atoms.
#   [rst :16@N3 :26@N1 r1 2 r2 2.5 r3 3.1 r4 5 rk2 10.0 rk3 10.0 out distance.rst]
# 	Mask [:16@N3] corresponds to 1 atoms.
# 	Mask [:26@N1] corresponds to 1 atoms.
#   [rst :15@N3 :27@N1 r1 2 r2 2.5 r3 3.1 r4 5 rk2 10.0 rk3 10.0 out distance.rst]
# 	Mask [:15@N3] corresponds to 1 atoms.
# 	Mask [:27@N1] corresponds to 1 atoms.
#   [rst :11@N1 :28@N3 r1 2 r2 2.5 r3 3.1 r4 5 rk2 10.0 rk3 10.0 out distance.rst]
# 	Mask [:11@N1] corresponds to 1 atoms.
# 	Mask [:28@N3] corresponds to 1 atoms.
#   [rst :10@N3 :29@N1 r1 2 r2 2.5 r3 3.1 r4 5 rk2 10.0 rk3 10.0 out distance.rst]
# 	Mask [:10@N3] corresponds to 1 atoms.
# 	Mask [:29@N1] corresponds to 1 atoms.
#   [rst :9@N3 :30@N1 r1 2 r2 2.5 r3 3.1 r4 5 rk2 10.0 rk3 10.0 out distance.rst]
# 	Mask [:9@N3] corresponds to 1 atoms.
# 	Mask [:30@N1] corresponds to 1 atoms.
#   [rst :8@N1 :31@N3 r1 2 r2 2.5 r3 3.1 r4 5 rk2 10.0 rk3 10.0 out distance.rst]
# 	Mask [:8@N1] corresponds to 1 atoms.
# 	Mask [:31@N3] corresponds to 1 atoms.
#   [rst :7@N3 :32@N1 r1 2 r2 2.5 r3 3.1 r4 5 rk2 10.0 rk3 10.0 out distance.rst]
# 	Mask [:7@N3] corresponds to 1 atoms.
# 	Mask [:32@N1] corresponds to 1 atoms.
#   [rst :6@N3 :33@N1 r1 2 r2 2.5 r3 3.1 r4 5 rk2 10.0 rk3 10.0 out distance.rst]
# 	Mask [:6@N3] corresponds to 1 atoms.
# 	Mask [:33@N1] corresponds to 1 atoms.
#   [rst :5@N3 :34@N1 r1 2 r2 2.5 r3 3.1 r4 5 rk2 10.0 rk3 10.0 out distance.rst]
# 	Mask [:5@N3] corresponds to 1 atoms.
# 	Mask [:34@N1] corresponds to 1 atoms.
#   [rst :4@N3 :35@N1 r1 2 r2 2.5 r3 3.1 r4 5 rk2 10.0 rk3 10.0 out distance.rst]
# 	Mask [:4@N3] corresponds to 1 atoms.
# 	Mask [:35@N1] corresponds to 1 atoms.
#   [rst :3@N1 :36@N3 r1 2 r2 2.9 r3 4.1 r4 6 rk2 10.0 rk3 10.0 out distance.rst]
# 	Mask [:3@N1] corresponds to 1 atoms.
# 	Mask [:36@N3] corresponds to 1 atoms.
#   [rst :2@N1 :37@N3 r1 2 r2 2.5 r3 3.1 r4 5 rk2 10.0 rk3 10.0 out distance.rst]
# 	Mask [:2@N1] corresponds to 1 atoms.
# 	Mask [:37@N3] corresponds to 1 atoms.
#   [rst :1@N1 :38@N3 r1 2 r2 2.5 r3 3.1 r4 5 rk2 10.0 rk3 10.0 out distance.rst]
# 	Mask [:1@N1] corresponds to 1 atoms.
# 	Mask [:38@N3] corresponds to 1 atoms.
# TIME: Total execution time: 0.0069 seconds.
# --------------------------------------------------------------------------------
# To cite CPPTRAJ use:
# Daniel R. Roe and Thomas E. Cheatham, III, "PTRAJ and CPPTRAJ: Software for
#   Processing and Analysis of Molecular Dynamics Trajectory Data". J. Chem.
#   Theory Comput., 2013, 9 (7), pp 3084-3095.
#
# Submitted batch job 214190
# Submitted batch job 214191
# Submitted batch job 214192
# /gene/home/ldw/Desktop/RNA_ensemble/md/pri-miR166f_ljbb_opc3_400K_500ns_0.12k_0.02mg
# Water molecules: 25769
# -I: Adding /gene/home/ldw/miniconda3/envs/amber_test/dat/leap/prep to search path.
# -I: Adding /gene/home/ldw/miniconda3/envs/amber_test/dat/leap/lib to search path.
# -I: Adding /gene/home/ldw/miniconda3/envs/amber_test/dat/leap/parm to search path.
# -I: Adding /gene/home/ldw/miniconda3/envs/amber_test/dat/leap/cmd to search path.
# -f: Source system.tleap.
#
# Welcome to LEaP!
# (no leaprc in search path)
# Sourcing: ./system.tleap
# ----- Source: /gene/home/ldw/miniconda3/envs/amber_test/dat/leap/cmd/leaprc.RNA.LJbb
# ----- Source of /gene/home/ldw/miniconda3/envs/amber_test/dat/leap/cmd/leaprc.RNA.LJbb done
# Log file: ./leap.log
# Loading parameters: /gene/home/ldw/miniconda3/envs/amber_test/dat/leap/parm/parm10.dat
# Reading title:
# PARM99 + frcmod.ff99SB + frcmod.parmbsc0 + OL3 for RNA
# Loading library: /gene/home/ldw/miniconda3/envs/amber_test/dat/leap/lib/nucleic12.LJbb-RNA.lib
# Loading library: /gene/home/ldw/miniconda3/envs/amber_test/dat/leap/lib/terminalphos.LJbb-RNA.lib
# Loading parameters: /gene/home/ldw/miniconda3/envs/amber_test/dat/leap/parm/frcmod.RNA.LJbb
# Reading force field modification type file (frcmod)
# Reading title:
# Steinbrecher-Latzer-Case Phosphate Oxygen parameters (JCTC, 8, 4405-12, 2012)
# ----- Source: /gene/home/ldw/miniconda3/envs/amber_test/dat/leap/cmd/leaprc.water.opc3
# ----- Source of /gene/home/ldw/miniconda3/envs/amber_test/dat/leap/cmd/leaprc.water.opc3 done
# Loading library: /gene/home/ldw/miniconda3/envs/amber_test/dat/leap/lib/atomic_ions.lib
# Loading library: /gene/home/ldw/miniconda3/envs/amber_test/dat/leap/lib/solvents.lib
# Loading parameters: /gene/home/ldw/miniconda3/envs/amber_test/dat/leap/parm/frcmod.opc3
# Reading force field modification type file (frcmod)
# Reading title:
# OPC3 Water Model (Izadi and Onufriev,  145, 074501, 2016)
# Loading parameters: /gene/home/ldw/miniconda3/envs/amber_test/dat/leap/parm/frcmod.ionslm_126_opc3
# Reading force field modification type file (frcmod)
# Reading title:
# Li/Merz ion parameters of atomic ions for the OPC3 water model (12-6 set)
# Loading PDB file: ./system.pdb
#   Added missing heavy atom: .R<C5 1>.A<O5' 2>
#   total atoms in file: 1914
#   Leap added 5 missing atoms according to residue templates:
#        1 Heavy
#        4 H / lone pairs
# Checking Unit.
#
# /gene/home/ldw/miniconda3/envs/amber_test/bin/teLeap: Warning!
# The unperturbed charge of the unit (-60.000000) is not zero.
#
# /gene/home/ldw/miniconda3/envs/amber_test/bin/teLeap: Note.
# Ignoring the warning from Unit Checking.
#
# Building topology.
# Building atom parameters.
# Building bond parameters.
# Building angle parameters.
# Building proper torsion parameters.
# Building improper torsion parameters.
#  total 395 improper torsions applied
# Building H-Bond parameters.
# Incorporating Non-Bonded adjustments.
# Not Marking per-residue atom chain types.
# Marking per-residue atom chain types.
#  (no restraints)
# Writing pdb file: system.check.nosol.pdb
# Scaling up box by a factor of 1.109426 to meet diagonal cut criterion
#   Solute vdw bounding box:              27.638 32.253 91.950
#   Total bounding box for atom centers:  118.576 118.576 118.576
#       (box expansion for 'iso' is 340.1%)
#   Solvent unit box:                     18.682 18.750 18.542
#   Volume: 854876.745 A^3 (oct)
#   Total mass 483941.940 amu,  Density 0.940 g/cc
#   Added 25799 residues.
# Adding 9 counter ions to "complex". 25790 solvent molecules will remain.
# 0: Placed MG in complex at (-9.91, -35.99, -16.66).
# 0: Placed MG in complex at (-8.06, 49.05, 16.46).
# 0: Placed MG in complex at (-24.51, 14.77, 15.97).
# 0: Placed MG in complex at (-0.41, 24.54, -21.01).
# 0: Placed MG in complex at (38.23, -16.29, -32.85).
# 0: Placed MG in complex at (-15.91, 32.48, 43.00).
# 0: Placed MG in complex at (21.78, -11.75, -51.33).
# 0: Placed MG in complex at (9.13, -49.50, 18.73).
# 0: Placed MG in complex at (-7.69, -43.42, 24.15).
# Adding 55 counter ions to "complex". 25735 solvent molecules will remain.
# 0: Placed K+ in complex at (21.82, 5.48, -9.89).
# 0: Placed K+ in complex at (-3.17, -22.12, 26.59).
# 0: Placed K+ in complex at (-16.20, -28.39, -35.39).
# 0: Placed K+ in complex at (-37.29, 34.68, 7.56).
# 0: Placed K+ in complex at (48.89, -1.38, 40.85).
# 0: Placed K+ in complex at (-20.04, -22.06, 8.51).
# 0: Placed K+ in complex at (28.15, 26.84, -29.44).
# 0: Placed K+ in complex at (-28.41, -17.78, -37.77).
# 0: Placed K+ in complex at (30.54, 28.57, 22.93).
# 0: Placed K+ in complex at (-0.49, 47.31, -34.22).
# 0: Placed K+ in complex at (-19.46, -15.54, -12.53).
# 0: Placed K+ in complex at (10.12, -3.76, -57.92).
# 0: Placed K+ in complex at (32.57, -2.12, 29.79).
# 0: Placed K+ in complex at (-20.80, 9.41, -20.68).
# 0: Placed K+ in complex at (-27.00, -31.62, -25.42).
# 0: Placed K+ in complex at (1.87, 5.56, -17.21).
# 0: Placed K+ in complex at (-19.62, -33.60, 31.91).
# 0: Placed K+ in complex at (44.07, -28.97, -20.59).
# 0: Placed K+ in complex at (-37.78, 1.51, -33.30).
# 0: Placed K+ in complex at (21.36, 19.30, -32.90).
# 0: Placed K+ in complex at (1.55, -29.43, 6.08).
# 0: Placed K+ in complex at (13.71, 42.28, 10.71).
# 0: Placed K+ in complex at (29.24, -0.45, 27.43).
# 0: Placed K+ in complex at (-19.32, 13.78, 7.61).
# 0: Placed K+ in complex at (-1.28, 23.66, 7.93).
# 0: Placed K+ in complex at (47.39, 7.11, 28.44).
# 0: Placed K+ in complex at (1.79, -3.32, 31.91).
# 0: Placed K+ in complex at (5.00, 15.53, 36.12).
# 0: Placed K+ in complex at (-20.16, -42.17, -23.66).
# 0: Placed K+ in complex at (27.79, -9.60, 20.24).
# 0: Placed K+ in complex at (13.13, 5.80, -44.53).
# 0: Placed K+ in complex at (31.44, 38.41, -5.04).
# 0: Placed K+ in complex at (-9.20, 49.87, 18.75).
# 0: Placed K+ in complex at (1.91, 53.61, 22.94).
# 0: Placed K+ in complex at (0.76, 36.71, -11.05).
# 0: Placed K+ in complex at (-1.99, 14.45, 6.12).
# 0: Placed K+ in complex at (13.76, -40.66, -0.89).
# 0: Placed K+ in complex at (41.39, 1.93, 8.36).
# 0: Placed K+ in complex at (-22.71, 12.54, -29.48).
# 0: Placed K+ in complex at (38.18, 33.75, -3.78).
# 0: Placed K+ in complex at (-48.83, -32.32, 2.40).
# 0: Placed K+ in complex at (24.39, -18.36, 9.80).
# 0: Placed K+ in complex at (25.54, -12.78, 32.65).
# 0: Placed K+ in complex at (44.43, 38.20, 13.37).
# 0: Placed K+ in complex at (-5.17, 38.56, -41.94).
# 0: Placed K+ in complex at (46.28, 20.14, 19.89).
# 0: Placed K+ in complex at (-4.74, -27.42, 29.79).
# 0: Placed K+ in complex at (23.68, 28.88, 22.39).
# 0: Placed K+ in complex at (47.86, 37.90, -4.27).
# 0: Placed K+ in complex at (-19.28, 13.75, -18.86).
# 0: Placed K+ in complex at (-44.20, -17.68, 23.45).
# 0: Placed K+ in complex at (-43.22, -32.02, 17.91).
# 0: Placed K+ in complex at (-22.36, -42.40, -25.39).
# 0: Placed K+ in complex at (37.60, 8.84, 27.11).
# 0: Placed K+ in complex at (46.11, -11.96, -10.15).
#
# /gene/home/ldw/miniconda3/envs/amber_test/bin/teLeap: Warning!
# addIonsRand: 1st Ion & target unit have charges of the same sign:
#      unit charge = 13; ion1 charge = 1;
#      can't neutralize.
# 13 Cl- ions required to neutralize.
# Adding 13 counter ions to "complex". 25722 solvent molecules will remain.
# 0: Placed Cl- in complex at (25.44, -10.44, -51.07).
# 0: Placed Cl- in complex at (34.85, 23.51, -29.45).
# 0: Placed Cl- in complex at (-20.48, 8.23, -55.52).
# 0: Placed Cl- in complex at (32.92, 47.03, 5.98).
# 0: Placed Cl- in complex at (-21.39, -6.77, -4.08).
# 0: Placed Cl- in complex at (-15.47, 3.56, -56.67).
# 0: Placed Cl- in complex at (13.05, -35.99, -0.66).
# 0: Placed Cl- in complex at (15.56, -8.81, -45.04).
# 0: Placed Cl- in complex at (-13.59, 45.56, -0.50).
# 0: Placed Cl- in complex at (27.37, -10.93, -38.79).
# 0: Placed Cl- in complex at (7.66, 52.81, -21.43).
# 0: Placed Cl- in complex at (28.92, 6.16, -20.89).
# 0: Placed Cl- in complex at (40.41, 15.89, -29.49).
# Total unperturbed charge:  -0.000000
# Total perturbed charge:    -0.000000
# Checking Unit.
# Building topology.
# Building atom parameters.
# Building bond parameters.
# Building angle parameters.
# Building proper torsion parameters.
# Building improper torsion parameters.
#  total 395 improper torsions applied
# Building H-Bond parameters.
# Incorporating Non-Bonded adjustments.
# Not Marking per-residue atom chain types.
# Marking per-residue atom chain types.
#   (Residues lacking connect0/connect1 -
#    these don't have chain types marked:
#
# 	res	total affected
#
# 	WAT	25722
#   )
#  (no restraints)
# Writing pdb file: system.check.pdb
#    printing CRYST1 record to PDB file with box info
# 	Quit
#
# Exiting LEaP: Errors = 0; Warnings = 2; Notes = 1.
#
#                         Y O U      H A V E      B E E N
#                                _
#                             ==(W{==========-      /===-
#                               ||  (.--.)         /===-_---~~~~~~~~~------____
#                               | \_,|**|,__      |===-~___                _,-' `
#                  -==\\        `\ ' `--'   ),    `//~\\   ~~~~`---.___.-~~
#              ______-==|        /`\_. .__/\ \    | |  \\           _-~`
#        __--~~~  ,-/-==\\      (   | .  |~~~~|   | |   `\        ,'
#     _-~       /'    |  \\     )__/==0==-\<>/   / /      \      /
#   .'        /       |   \\      /~\___/~~\/  /' /        \   /'
#  /  ____  /         |    \`\.__/-~~   \  |_/'  /          \/'
# /-'~    ~~~~~---__  |     ~-/~         ( )   /'        _--~`
#                   \_|      /        _) | ;  ),   __--~~
#                     '~~--_/      _-~/- |/ \   '-~ \
#                    {\__--_/}    / \\_>-|)<__\      \
#                    /'   (_/  _-~  | |__>--<__|      |
#                   |   _/) )-~     | |__>--<__|      |
#                   / /~ ,_/       / /__>---<__/      |
#                  o-o _//        /-~_>---<__-~      /
#                  (^(~          /~_>---<__-      _-~
#                 ,/|           /__>--<__/     _-~
#              ,//('(          |__>--<__|     /                  .----_
#             ( ( '))          |__>--<__|    |                 /' _---_~\
#          `-)) )) (           |__>--<__|    |               /'  /     ~\`\
#         ,/,'//( (             \__>--<__\    \            /'  //        ||
#       ,( ( ((, ))              ~-__>--<_~-_  ~--____---~' _/'/        /'
#     `~/  )` ) ,/|                 ~-_~>--<_/-__       __-~ _/
#   ._-~//( )/ )) `                    ~~-'_/_/ /~~~~~~~__--~
#    ;'( ')/ ,)(                              ~~~~~~~~~~
#   ' ') '( (/
#     '   '  `
#                                   P A R M E D
#
# ParmEd: a Parameter file Editor
#
#
# Loaded Amber topology file system.top
# ['system.parmed']
# Reading actions from system.parmed
#
# Repartitioning hydrogen masses to 3.024 daltons. Not changing water hydrogen masses.
# Outputting Amber topology file system.hmr.top
# Done!
#
# CPPTRAJ: Trajectory Analysis. V6.18.1 (AmberTools)
#     ___  ___  ___  ___
#      | \/ | \/ | \/ |
#     _|_/\_|_/\_|_/\_|_
#
# | Date/time: 08/10/25 18:58:26
# | Available memory: 20.620 GB
#
# INPUT: Reading input from 'rst.cpptraj'
#   [parm system.check.nosol.pdb]
# 	Reading 'system.check.nosol.pdb' as PDB File
# 	Reading bond info from CONECT records.
# 	Not reading bond info from LINK records.
# Warning: PDB line length is short (67 chars, expected 80).
# 	Determining bond info from distances.
# Warning: Determining bond length parameters from element types for 'system.check.nosol.pdb'.
#   [rst :29@N3 :38@N1 r1 2 r2 2.5 r3 3.1 r4 5 rk2 10.0 rk3 10.0 out distance.rst]
# 	Mask [:29@N3] corresponds to 1 atoms.
# 	Mask [:38@N1] corresponds to 1 atoms.
#   [rst :28@N1 :39@N3 r1 2 r2 2.5 r3 3.1 r4 5 rk2 10.0 rk3 10.0 out distance.rst]
# 	Mask [:28@N1] corresponds to 1 atoms.
# 	Mask [:39@N3] corresponds to 1 atoms.
#   [rst :27@N1 :40@N3 r1 2 r2 2.9 r3 4.1 r4 6 rk2 10.0 rk3 10.0 out distance.rst]
# 	Mask [:27@N1] corresponds to 1 atoms.
# 	Mask [:40@N3] corresponds to 1 atoms.
#   [rst :26@N1 :41@N3 r1 2 r2 2.5 r3 3.1 r4 5 rk2 10.0 rk3 10.0 out distance.rst]
# 	Mask [:26@N1] corresponds to 1 atoms.
# 	Mask [:41@N3] corresponds to 1 atoms.
#   [rst :23@N3 :44@N1 r1 2 r2 2.5 r3 3.1 r4 5 rk2 10.0 rk3 10.0 out distance.rst]
# 	Mask [:23@N3] corresponds to 1 atoms.
# 	Mask [:44@N1] corresponds to 1 atoms.
#   [rst :22@N1 :45@N3 r1 2 r2 2.5 r3 3.1 r4 5 rk2 10.0 rk3 10.0 out distance.rst]
# 	Mask [:22@N1] corresponds to 1 atoms.
# 	Mask [:45@N3] corresponds to 1 atoms.
#   [rst :21@N1 :47@N3 r1 2 r2 2.5 r3 3.1 r4 5 rk2 10.0 rk3 10.0 out distance.rst]
# 	Mask [:21@N1] corresponds to 1 atoms.
# 	Mask [:47@N3] corresponds to 1 atoms.
#   [rst :20@N1 :48@N3 r1 2 r2 2.5 r3 3.1 r4 5 rk2 10.0 rk3 10.0 out distance.rst]
# 	Mask [:20@N1] corresponds to 1 atoms.
# 	Mask [:48@N3] corresponds to 1 atoms.
#   [rst :19@N1 :49@N3 r1 2 r2 2.5 r3 3.1 r4 5 rk2 10.0 rk3 10.0 out distance.rst]
# 	Mask [:19@N1] corresponds to 1 atoms.
# 	Mask [:49@N3] corresponds to 1 atoms.
#   [rst :18@N1 :50@N3 r1 2 r2 2.5 r3 3.1 r4 5 rk2 10.0 rk3 10.0 out distance.rst]
# 	Mask [:18@N1] corresponds to 1 atoms.
# 	Mask [:50@N3] corresponds to 1 atoms.
#   [rst :17@N3 :51@N1 r1 2 r2 2.5 r3 3.1 r4 5 rk2 10.0 rk3 10.0 out distance.rst]
# 	Mask [:17@N3] corresponds to 1 atoms.
# 	Mask [:51@N1] corresponds to 1 atoms.
#   [rst :15@N1 :55@N3 r1 2 r2 2.5 r3 3.1 r4 5 rk2 10.0 rk3 10.0 out distance.rst]
# 	Mask [:15@N1] corresponds to 1 atoms.
# 	Mask [:55@N3] corresponds to 1 atoms.
#   [rst :14@N1 :56@N3 r1 2 r2 2.5 r3 3.1 r4 5 rk2 10.0 rk3 10.0 out distance.rst]
# 	Mask [:14@N1] corresponds to 1 atoms.
# 	Mask [:56@N3] corresponds to 1 atoms.
#   [rst :13@N1 :57@N3 r1 2 r2 2.5 r3 3.1 r4 5 rk2 10.0 rk3 10.0 out distance.rst]
# 	Mask [:13@N1] corresponds to 1 atoms.
# 	Mask [:57@N3] corresponds to 1 atoms.
#   [rst :12@N3 :58@N1 r1 2 r2 2.5 r3 3.1 r4 5 rk2 10.0 rk3 10.0 out distance.rst]
# 	Mask [:12@N3] corresponds to 1 atoms.
# 	Mask [:58@N1] corresponds to 1 atoms.
# TIME: Total execution time: 0.0152 seconds.
# --------------------------------------------------------------------------------
# To cite CPPTRAJ use:
# Daniel R. Roe and Thomas E. Cheatham, III, "PTRAJ and CPPTRAJ: Software for
#   Processing and Analysis of Molecular Dynamics Trajectory Data". J. Chem.
#   Theory Comput., 2013, 9 (7), pp 3084-3095.
#
# Submitted batch job 214193
# Submitted batch job 214194
# Submitted batch job 214195

# %%
import os
import subprocess
import numpy as np
import math
import sys


def hie_pocket_topN(work_pwd, parm_pwd, traj_pwds, out_pwd, out_prefix, frame_per_ns, frame_interval, start_ns, end_ns, pocket_resids, N=1, nofit=False):
    # cluster setting
    if len(pocket_resids) > 0:
        align_resids = ":"
        for start_pos, end_pos in pocket_resids:
            align_resids += f"{start_pos}-{end_pos},"
        align_selection = align_resids + "@C3'"
    else:
        align_selection = "@C3'"
    if nofit:
        fit_parm = "nofit"
    else:
        fit_parm = ""
    # file name
    start_pwd = os.getcwd()
    os.chdir(work_pwd)
    start_frame = int(frame_per_ns * start_ns)
    end_frame = int(frame_per_ns * end_ns)
    trajins = ""
    for traj_pwd in traj_pwds:
        if os.path.exists(traj_pwd):
            trajins += f"trajin {traj_pwd} {start_frame} {end_frame} {frame_interval}\n"
    with open(f"hie_pocket_{start_ns}-{end_ns}ns_N{N}_i{frame_interval}.cpptraj", "w") as ifile:
        ifile.write(f"""
parm {parm_pwd}
{trajins}
autoimage
rmsd {align_selection}
cluster clusters {N} rms {align_selection} {fit_parm} repout {out_pwd}/{out_prefix}_pocket_{start_ns}-{end_ns}ns_hie repfmt pdb summary {out_pwd}/{out_prefix}_pocket_{start_ns}-{end_ns}ns_hie.dat
run
""")
    subprocess.run(f"cpptraj -i hie_pocket_{start_ns}-{end_ns}ns_N{N}_i{frame_interval}.cpptraj > cpptraj.log", shell=True)
    os.chdir(start_pwd)
    return

def find_all_positions(text, pattern):
    positions = []
    start = 0
    while start < len(text):
        idx = text.find(pattern, start)
        if idx == -1:
            break
        positions.append(idx)
        start = idx + 1  # 从下一个位置继续搜索
    return positions

def get_pocket_resid(seq, pocket_seq):
    if pocket_seq == None:
        return []
    pocket_seqs = pocket_seq.strip("...").split("...")
    pocket_resids = []
    for sub_seq in pocket_seqs:
        positions = find_all_positions(seq, sub_seq)
        if len(positions) != 1:
            raise
        pocket_resids.append((positions[0], positions[0]+len(sub_seq)))
    return pocket_resids


traj_ns = 500  # 500 ns
num_of_replica = 3  # 平行轨迹数
box_d = 12  # 水盒子大小
k_m = 0.12  # 0.12 M K+
mg_m = 0.02  # 0.02 M Mg2+
temp = 400  # 400 K
ff = "ljbb"  # RNA force field
wat_ff = "opc3"  # water force field
input_txt = "/gene/home/ldw/Desktop/RNA_ensemble/input/dna_repair.txt"
save_dir = "/gene/home/ldw/Desktop/RNA_ensemble/input/dna_repair"  # 初始pdb结构路径
md_pwd = "/gene/home/ldw/Desktop/RNA_ensemble/md/dna_repair"  # md路径
out_pwd = "/gene/home/ldw/Desktop/RNA_ensemble/analysis/dna_repair.txt"  # 聚类输出路径
frame_per_ns = 10
start_ns = 0
end_ns = traj_ns
N = 10  # 聚类输出结构数目
frame_interval = 2

os.makedirs(out_pwd, exist_ok=True)
rna_infos = {}
with open(input_txt, "r") as ifile:
    for line in ifile:
        words = line.split()
        rna_infos[words[0]] = {"seq": words[1], "rna_ss": words[2]}
        pocket_resids = []
        for pocket_resid in words[3:]:
            pocket_resid = pocket_resid.split("-")
            pocket_resids.append((int(pocket_resid[0]), int(pocket_resid[1])))
        rna_infos[words[0]]["pocket_resids"] = pocket_resids

for rna_name in list(rna_infos.keys())[:]:
    md_name = f"{rna_name}_{ff}_{wat_ff}_{temp}K_{traj_ns}ns_{k_m}k_{mg_m}mg"
    work_pwd = os.path.join(md_pwd, md_name)
    parm_pwd = "system.nosol.top"
    traj_pwds = [f"system.{temp}K.{i}.nc" for i in range(num_of_replica)]
    pocket_resids = rna_infos[rna_name]["pocket_resids"]
    print(rna_name, pocket_resids)
    hie_pocket_topN(work_pwd, parm_pwd, traj_pwds, out_pwd, md_name, frame_per_ns, frame_interval, start_ns, end_ns, pocket_resids, N=N, nofit=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 94
#      92         for pocket_resid in words[3:]:
#      93             pocket_resid = pocket_resid.split("-")
# ---> 94             pocket_resids.append((int(pocket_resid[0]), int(pocket_resid[1])))
#      95         rna_infos[words[0]]["pocket_resids"] = pocket_resids
#      97 for rna_name in list(rna_infos.keys())[:]:
#
# ValueError: invalid literal for int() with base 10: '15,'
